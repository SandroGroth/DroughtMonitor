# %% [markdown]
# #Drought Monitoring based on MODIS VI time series data and Google Earth Engine

# %% [markdown]
# ## 01. Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/My Drive')
print('Working directory set to : %s' % os.getcwd())
# Out:
# Working directory set to : /content/drive/My Drive

# %% [markdown]
# ## 02. Setting up working directory

# %%
base_path = "/content/drive/My Drive/DroughtMonitor"

data_path = os.path.join(base_path, "Data")
raster_data_path = os.path.join(data_path, "Raster")
normal_NDVI_path = os.path.join(raster_data_path, "Normal_NDVIs")
vector_data_path = os.path.join(data_path, "Vector")

utils_path = os.path.join(base_path, "Utils")

# %%
import os

try:
  os.mkdir(base_path)
  print("Created working directory: %s" % base_path)
  os.mkdir(data_path)
  print("Created Data directory: %s" % data_path)
  os.mkdir(raster_data_path)
  print("Created Data directory: %s" % raster_data_path)
  os.mkdir(vector_data_path)
  print("Created Data directory: %s" % vector_data_path)
  os.mkdir(normal_NDVI_path)
  print("Created Data directory: %s" % normal_NDVI_path)
  os.mkdir(utils_path)
  print("Created Utils directory: %s" % utils_path)
except OSError as e:
  print("Directory creation failed: %s" % e)
else:
  print("All paths created successfully.")
# Out:
# Created working directory: /content/drive/My Drive/DroughtMonitor
# Created Data directory: /content/drive/My Drive/DroughtMonitor/Data
# Created Data directory: /content/drive/My Drive/DroughtMonitor/Data/Raster
# Created Data directory: /content/drive/My Drive/DroughtMonitor/Data/Vector
# Created Data directory: /content/drive/My Drive/DroughtMonitor/Data/Raster/Normal_NDVIs
# Created Utils directory: /content/drive/My Drive/DroughtMonitor/Utils
# All paths created successfully.

# %% [markdown]
# # 03. Install eeUtils

# %%
# TODO
# Currently, all functions are defined and debugged in the Notebooks itself and
# will get implemented in eeUtils in near future.
